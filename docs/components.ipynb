# %% [markdown]
# # Optimization components

# %% [markdown]
# This notebook covers the available optimization classes from which the component list is formed. If user-dependent inputs are required, we added a string placeholder with "<>". Further information on the component-specific parameters can be found in the API.
#
# > Note: machine learning outcome model-based components may require inputs on the data columns. Check out the corresponding notebook provided in the examples for information on how to set up the columns list.

# %% [markdown]
# ## Conventional components

# %% [markdown]
# ### Dose Uniformity
# <i>A class for the standard deviation of the dose</i>

# %%
from pyanno4rt.optimization.components import DoseUniformity

DoseUniformity(
    segment='<your_segment>',
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Equivalent Uniform Dose
# <i>A class for the equivalent uniform dose</i>

# %%
from pyanno4rt.optimization.components import EquivalentUniformDose

EquivalentUniformDose(
    segment='<your_segment>',
    target_eud='<your_target_eud>',
    volume_parameter='<your_volume_parameter>',
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Maximum DVH
# <i>A class for the maximum dose to a specific volume share</i>

# %%
from pyanno4rt.optimization.components import MaximumDVH

MaximumDVH(
    segment='<your_segment>',
    target_dose='<your_target_dose>',
    quantile_volume='<your_quantile_volume>',
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Mean Dose
# <i>A class for the mean dose</i>

# %%
from pyanno4rt.optimization.components import MeanDose

MeanDose(
    segment='<your_segment>',
    target_dose='<your_target_dose>',
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Minimum DVH
# <i>A class for the minimum volume share to a specific dose value</i>

# %%
from pyanno4rt.optimization.components import MinimumDVH

MinimumDVH(
    segment='<your_segment>',
    target_dose='<your_target_dose>',
    quantile_volume='<your_quantile_volume>',
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Squared Deviation
# <i>A class for the quadratic deviation from a target dose</i>

# %%
from pyanno4rt.optimization.components import SquaredDeviation

SquaredDeviation(
    segment='<your_segment>',
    target_dose='<your_target_dose>',
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Squared Overdosing
# <i>A class for the quadratic positive deviation from a maximum dose</i>

# %%
from pyanno4rt.optimization.components import SquaredOverdosing

SquaredOverdosing(
    segment='<your_segment>',
    maximum_dose='<your_maximum_dose>',
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Squared Underdosing
# <i>A class for the quadratic negative deviation from a minimum dose</i>

# %%
from pyanno4rt.optimization.components import SquaredUnderdosing

SquaredUnderdosing(
    segment='<your_segment>',
    minimum_dose='<your_minimum_dose>',
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ## Radiobiological model-based components

# %% [markdown]
# ### LQ Poisson TCP
# <i>A class for the linear-quadratic Poisson TCP component</i>

# %%
from pyanno4rt.optimization.components import LQPoissonTCP

LQPoissonTCP(
    segment='<your_segment>',
    alpha='<your_alpha>',
    beta='<your_beta>',
    volume_parameter='<your_volume_parameter>',
    number_of_fractions='<your_number_of_fractions>',
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Lyman-Kutcher-Burman NTCP
# <i>A class for the Lyman-Kutcher-Burman NTCP component</i>

# %%
from pyanno4rt.optimization.components import LymanKutcherBurmanNTCP

LymanKutcherBurmanNTCP(
    segment='<your_segment>',
    tolerance_dose_50='<your_td50>',
    slope_parameter='<your_slope_parameter>',
    volume_parameter='<your_volume_parameter>',
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ## Machine learning model-based components

# %% [markdown]
# ### Decision Tree (N)TCP
# <i>A class for the decision tree-based (N)TCP component</i>

# %%
from pyanno4rt.learning import ModelParameters
from pyanno4rt.optimization.components import (
    DecisionTreeNTCP, DecisionTreeTCP) # depending on outcome type
from pyanno4rt.learning.features import (
    DynamicFeature, Label, StaticFeature) # depending on data column types
from pyanno4rt.learning.tune_spaces import TuneSpaceDT

DecisionTreeNTCP(  # or DecisionTreeTCP
    segment='<your_segment>',
    model_parameters=ModelParameters(
        model_label='<your_model_label>',
        model_folder_path=None,
        data_path='<your_data_path>',
        data_columns='<your_data_columns>',
        preprocessing_steps=['Identity'],
        tune_space=TuneSpaceDT(
            criterion=['gini', 'entropy'],
            splitter=['best', 'random'],
            max_depth=[5],
            min_samples_split=[0.0, 1.0],
            min_samples_leaf=[0.0, 0.5],
            min_weight_fraction_leaf=[0.0, 0.5],
            max_features=[0],
            class_weight=[None, 'balanced'],
            ccp_alpha=[0.0, 1.0]
        ),
        tune_evaluations=50,
        tune_score='Logloss',
        tune_splits=5,
        tune_repeats=1,
        inspect=False,
        evaluate=False,
        oof_splits=5,
        oof_repeats=1,
        write_features=False,
        display_options=DisplayOptions(
            graphs=['AUC-ROC', 'AUC-PR', 'F1'],
            kpis=[
                'Logloss', 'Brier score', 'Subset accuracy', 'Cohen Kappa',
                'Hamming loss', 'Jaccard score', 'Precision', 'Recall',
                'F1 score', 'MCC', 'AUC']
        )
    ),
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### K-Nearest Neighbors (N)TCP
# <i>A class for the k-nearest neighbors-based (N)TCP component</i>

# %%
from pyanno4rt.learning import ModelParameters
from pyanno4rt.optimization.components import (
    KNeighborsNTCP, KNeighborsTCP) # depending on outcome type
from pyanno4rt.learning.features import (
    DynamicFeature, Label, StaticFeature) # depending on data column types
from pyanno4rt.learning.tune_spaces import TuneSpaceKNN

KNeighborsNTCP(  # or KNeighborsTCP
    segment='<your_segment>',
    model_parameters=ModelParameters(
        model_label='<your_model_label>',
        model_folder_path=None,
        data_path='<your_data_path>',
        data_columns='<your_data_columns>',
        preprocessing_steps=['Identity'],
        tune_space=TuneSpaceKNN(
            n_neighbors=list(range(1, 11)),
            weights=['uniform', 'distance'],
            leaf_size=list(range(1, 501)),
            p=[1, 2, 3]
        ),
        tune_evaluations=50,
        tune_score='Logloss',
        tune_splits=5,
        tune_repeats=1,
        inspect=False,
        evaluate=False,
        oof_splits=5,
        oof_repeats=1,
        write_features=False,
        display_options=DisplayOptions(
            graphs=['AUC-ROC', 'AUC-PR', 'F1'],
            kpis=[
                'Logloss', 'Brier score', 'Subset accuracy', 'Cohen Kappa',
                'Hamming loss', 'Jaccard score', 'Precision', 'Recall',
                'F1 score', 'MCC', 'AUC']
        )
    ),
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Logistic Regression (N)TCP
# <i>A class for the logistic regression-based (N)TCP component</i>

# %%
from pyanno4rt.learning import ModelParameters
from pyanno4rt.optimization.components import (
    LogisticRegressionNTCP, LogisticRegressionTCP) # depending on outcome type
from pyanno4rt.learning.features import (
    DynamicFeature, Label, StaticFeature) # depending on data column types
from pyanno4rt.learning.tune_spaces import TuneSpaceLR

LogisticRegressionNTCP(  # or LogisticRegressionTCP
    segment='<your_segment>',
    model_parameters=ModelParameters(
        model_label='<your_model_label>',
        model_folder_path=None,
        data_path='<your_data_path>',
        data_columns='<your_data_columns>',
        preprocessing_steps=['Identity'],
        tune_space=TuneSpaceLR(
            C=[2**-5, 2**10],
            penalty=['l1', 'l2', 'elasticnet'],
            tol=[1e-4, 1e-5, 1e-6],
            class_weight=[None, 'balanced']
        ),
        tune_evaluations=50,
        tune_score='Logloss',
        tune_splits=5,
        tune_repeats=1,
        inspect=False,
        evaluate=False,
        oof_splits=5,
        oof_repeats=1,
        write_features=False,
        display_options=DisplayOptions(
            graphs=['AUC-ROC', 'AUC-PR', 'F1'],
            kpis=[
                'Logloss', 'Brier score', 'Subset accuracy', 'Cohen Kappa',
                'Hamming loss', 'Jaccard score', 'Precision', 'Recall',
                'F1 score', 'MCC', 'AUC']
        )
    ),
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Naive Bayes (N)TCP
# <i>A class for the naive Bayes-based (N)TCP component</i>

# %%
from pyanno4rt.learning import ModelParameters
from pyanno4rt.optimization.components import (
    NaiveBayesNTCP, NaiveBayesTCP) # depending on outcome type
from pyanno4rt.learning.features import (
    DynamicFeature, Label, StaticFeature) # depending on data column types
from pyanno4rt.learning.tune_spaces import TuneSpaceNB

NaiveBayesNTCP(  # or NaiveBayesTCP
    segment='<your_segment>',
    model_parameters=ModelParameters(
        model_label='<your_model_label>',
        model_folder_path=None,
        data_path='<your_data_path>',
        data_columns='<your_data_columns>',
        preprocessing_steps=['Identity'],
        tune_space=TuneSpaceNB(
            priors=[None] + [[i/10, 1-i/10] for i in range(1, 10)],
            var_smoothing=[1e-12, 1]
        ),
        tune_evaluations=50,
        tune_score='Logloss',
        tune_splits=5,
        tune_repeats=1,
        inspect=False,
        evaluate=False,
        oof_splits=5,
        oof_repeats=1,
        write_features=False,
        display_options=DisplayOptions(
            graphs=['AUC-ROC', 'AUC-PR', 'F1'],
            kpis=[
                'Logloss', 'Brier score', 'Subset accuracy', 'Cohen Kappa',
                'Hamming loss', 'Jaccard score', 'Precision', 'Recall',
                'F1 score', 'MCC', 'AUC']
        )
    ),
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Neural Network (N)TCP
# <i>A class for the neural network-based (N)TCP component</i>

# %%
from pyanno4rt.learning import ModelParameters
from pyanno4rt.optimization.components import (
    NeuralNetworkNTCP, NeuralNetworkTCP) # depending on outcome type
from pyanno4rt.learning.features import (
    DynamicFeature, Label, StaticFeature) # depending on data column types
from pyanno4rt.learning.tune_spaces import TuneSpaceNN

NeuralNetworkNTCP(  # or NeuralNetworkTCP
    segment='<your_segment>',
    model_parameters=ModelParameters(
        model_label='<your_model_label>',
        model_folder_path=None,
        data_path='<your_data_path>',
        data_columns='<your_data_columns>',
        preprocessing_steps=['Identity'],
        architecture='vanilla',
        max_hidden_layers=2,
        tune_space=TuneSpaceNN(
            hidden_neuron_number=[2**x for x in range(1, 12)],
            hidden_activation=[
                'elu', 'gelu', 'leaky_relu', 'linear',
                'relu', 'softmax', 'softplus', 'swish'],
            hidden_dropout_rate=[0.0, 0.1, 0.25, 0.5, 0.75],
            batch_size=[4, 8, 16, 32],
            learning_rate=[1e-5, 1e-2],
            optimizer=['Adam', 'Ftrl', 'SGD'],
            loss=['BCE', 'FocalBCE', 'KLD']
        ),
        tune_evaluations=50,
        tune_score='Logloss',
        tune_splits=5,
        tune_repeats=1,
        inspect=False,
        evaluate=False,
        oof_splits=5,
        oof_repeats=1,
        write_features=False,
        display_options=DisplayOptions(
            graphs=['AUC-ROC', 'AUC-PR', 'F1'],
            kpis=[
                'Logloss', 'Brier score', 'Subset accuracy', 'Cohen Kappa',
                'Hamming loss', 'Jaccard score', 'Precision', 'Recall',
                'F1 score', 'MCC', 'AUC']
        )
    ),
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Random Forest (N)TCP
# <i>A class for the random forest-based (N)TCP component</i>

# %%
from pyanno4rt.learning import ModelParameters
from pyanno4rt.optimization.components import (
    RandomForestNTCP, RandomForestTCP) # depending on outcome type
from pyanno4rt.learning.features import (
    DynamicFeature, Label, StaticFeature) # depending on data column types
from pyanno4rt.learning.tune_spaces import TuneSpaceRF

RandomForestNTCP(  # or RandomForestTCP
    segment='<your_segment>',
    model_parameters=ModelParameters(
        model_label='<your_model_label>',
        model_folder_path=None,
        data_path='<your_data_path>',
        data_columns='<your_data_columns>',
        preprocessing_steps=['Identity'],
        tune_space=TuneSpaceRF(
            n_estimators=[100],
            criterion=['gini', 'entropy'],
            max_depth=[5],
            min_samples_split=[0.0, 1.0],
            min_samples_leaf=[0.0, 0.5],
            min_weight_fraction_leaf=[0.0, 0.5],
            max_features=[0],
            bootstrap=[False, True],
            class_weight=[None, 'balanced'],
            ccp_alpha=[0.0, 1.0]
        ),
        tune_evaluations=50,
        tune_score='Logloss',
        tune_splits=5,
        tune_repeats=1,
        inspect=False,
        evaluate=False,
        oof_splits=5,
        oof_repeats=1,
        write_features=False,
        display_options=DisplayOptions(
            graphs=['AUC-ROC', 'AUC-PR', 'F1'],
            kpis=[
                'Logloss', 'Brier score', 'Subset accuracy', 'Cohen Kappa',
                'Hamming loss', 'Jaccard score', 'Precision', 'Recall',
                'F1 score', 'MCC', 'AUC']
        )
    ),
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)

# %% [markdown]
# ### Support Vector Machine (N)TCP
# <i>A class for the support vector machine-based (N)TCP component</i>

# %%
from pyanno4rt.learning import ModelParameters
from pyanno4rt.optimization.components import (
    SupportVectorMachineNTCP, SupportVectorMachineTCP) # depending on outcome type
from pyanno4rt.learning.features import (
    DynamicFeature, Label, StaticFeature) # depending on data column types
from pyanno4rt.learning.tune_spaces import TuneSpaceSVM

SupportVectorMachineNTCP(  # or SupportVectorMachineTCP
    segment='<your_segment>',
    model_parameters=ModelParameters(
        model_label='<your_model_label>',
        model_folder_path=None,
        data_path='<your_data_path>',
        data_columns='<your_data_columns>',
        preprocessing_steps=['Identity'],
        tune_space=TuneSpaceSVM(
            C=[2**-5, 2**10],
            kernel=['linear', 'poly', 'rbf', 'sigmoid'],
            degree=[3, 4, 5, 6],
            gamma=[0.01, 100],
            tol=[1e-4, 1e-5, 1e-6],
            class_weight=[None, 'balanced']
        ),
        tune_evaluations=50,
        tune_score='Logloss',
        tune_splits=5,
        tune_repeats=1,
        inspect=False,
        evaluate=False,
        oof_splits=5,
        oof_repeats=1,
        write_features=False,
        display_options=DisplayOptions(
            graphs=['AUC-ROC', 'AUC-PR', 'F1'],
            kpis=[
                'Logloss', 'Brier score', 'Subset accuracy', 'Cohen Kappa',
                'Hamming loss', 'Jaccard score', 'Precision', 'Recall',
                'F1 score', 'MCC', 'AUC']
        )
    ),
    component_type='objective',
    embedding='active',
    weight=1,
    rank=1,
    bounds=None,
    link=None,
    identifier=None,
    display=True)
